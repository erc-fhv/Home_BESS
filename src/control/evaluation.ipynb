# %%
import pandas as pd

# %%
mpc_result = pd.read_parquet("mpc_results.parquet")
mpc_result
# Out:
#                            netload_forecast_kw  set_netload_kw  p_ch_kw  \
# 2026-02-27 19:00:00+01:00             0.420302   -1.157970e+01      0.0
# 2026-02-27 19:15:00+01:00             0.445635   -1.155437e+01      0.0
# 2026-02-27 19:30:00+01:00             0.469580   -1.153042e+01      0.0
# 2026-02-27 19:45:00+01:00             0.478029   -6.507292e+00      0.0
# 2026-02-27 20:00:00+01:00             0.423846   -1.157615e+01      0.0
# ...                                        ...             ...      ...
# 2026-02-28 22:45:00+01:00             0.331886    1.233189e+01     12.0
# 2026-02-28 23:00:00+01:00             0.314248    4.662474e-09      0.0
# 2026-02-28 23:15:00+01:00             0.324231    3.242311e-01      0.0
# 2026-02-28 23:30:00+01:00             0.330340    1.233034e+01     12.0
# 2026-02-28 23:45:00+01:00             0.339179             NaN      NaN
#
#                             p_dis_kw  price_sell_eur_kwh  price_buy_eur_kwh
# ...

# %%
mpc_result.plot(y=["netload_forecast_kw"], figsize=(12, 6), title="MPC Control Results")
mpc_result.plot(y=["set_netload_kw"], figsize=(12, 6), title="MPC Control Results")
mpc_result.plot(y=["price_buy_eur_kwh"], figsize=(12, 6), title="MPC Control Results")
# Out:
# <Axes: title={'center': 'MPC Control Results'}>
